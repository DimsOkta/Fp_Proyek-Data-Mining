# %% [markdown]
# <a href="https://colab.research.google.com/github/DimsOkta/Fp_Proyek-Data-Mining/blob/main/Klasifikasi_Penyakit_Diabetes_Menggunakan_Support_Vector_Machine_(SVM).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# FINAL PROJECT PROYEK DATA MINING

# %% [markdown]
# Nama : Muhammad Dimas Oktavian <br>
# NIM  : 22.11.4736 <br>
#
# FINAL PROJECT PROYEK DATA MINING
# (Klasifikasi Penyakit Diabetes Menggunakan Support Vector Machine (SVM)) <br>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# ##Import Data

# %%
df = pd.read_csv('Diabetes.csv', index_col=0)
df
# Out:
#      Kehamilan  Glukosa  Tekanan Darah  Ketebalan Kulit  Insulin   BMI  \
# 0            6      148             72               35        0  33.6
# 1            1       85             66               29        0  26.6
# 2            8      183             64                0        0  23.3
# 3            1       89             66               23       94  28.1
# 4            0      137             40               35      168  43.1
# ..         ...      ...            ...              ...      ...   ...
# 763         10      101             76               48      180  32.9
# 764          2      122             70               27        0  36.8
# 765          5      121             72               23      112  26.2
# 766          1      126             60                0        0  30.1
# 767          1       93             70               31        0  30.4
#
#      DiabetesPedigreeFunction  Umur  Hasil
# 0                       0.627    50      1
# ...

# %% [markdown]
# ##Data Understanding

# %%
print("Data shape : ", df.shape)
# Out:
# Data shape :  (768, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Kehamilan                 768 non-null    int64
#  1   Glukosa                   768 non-null    int64
#  2   Tekanan Darah             768 non-null    int64
#  3   Ketebalan Kulit           768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Umur                      768 non-null    int64
#  8   Hasil                     768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 60.0 KB

# %%
df[['Kehamilan', 'Tekanan Darah', 'Umur', 'BMI']].describe()
# Out:
#         Kehamilan  Tekanan Darah        Umur         BMI
# count  768.000000     768.000000  768.000000  768.000000
# mean     3.845052      69.105469   33.240885   31.992578
# std      3.369578      19.355807   11.760232    7.884160
# min      0.000000       0.000000   21.000000    0.000000
# 25%      1.000000      62.000000   24.000000   27.300000
# 50%      3.000000      72.000000   29.000000   32.000000
# 75%      6.000000      80.000000   41.000000   36.600000
# max     17.000000     122.000000   81.000000   67.100000

# %%
df.Hasil.value_counts()
# Out:
# Hasil
# 0    500
# 1    268
# Name: count, dtype: int64

# %% [markdown]
# ##2.Cleaning Data

# %%
df.isnull().sum()
# Out:
# Kehamilan                   0
# Glukosa                     0
# Tekanan Darah               0
# Ketebalan Kulit             0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Umur                        0
# Hasil                       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ##3. Exploratory Data Analysis (EDA)

# %%
plt.figure(figsize=(6, 4))
sns.histplot(data=df, x='Umur', bins=10, kde=True, color='red')

plt.title('Distribusi Umur')
plt.xlabel('Umur')
plt.ylabel('Frekuensi')
plt.show()

# %%
from enum import auto
sns.set_palette("pastel")
df['Hasil'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Presentase Diabetes vs Non Diabetes')
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='Hasil', palette='rocket')

plt.title('Distribusi Hasil Diagnosis')
plt.xlabel('Hasil / label')
plt.ylabel('Frekuensi')
plt.show()
# Out:
# <ipython-input-11-13e25797b611>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Hasil', palette='rocket')

# %%
df.corr()
# Out:
#                           Kehamilan   Glukosa  Tekanan Darah  Ketebalan Kulit  \
# Kehamilan                  1.000000  0.129459       0.141282        -0.081672
# Glukosa                    0.129459  1.000000       0.152590         0.057328
# Tekanan Darah              0.141282  0.152590       1.000000         0.207371
# Ketebalan Kulit           -0.081672  0.057328       0.207371         1.000000
# Insulin                   -0.073535  0.331357       0.088933         0.436783
# BMI                        0.017683  0.221071       0.281805         0.392573
# DiabetesPedigreeFunction  -0.033523  0.137337       0.041265         0.183928
# Umur                       0.544341  0.263514       0.239528        -0.113970
# Hasil                      0.221898  0.466581       0.065068         0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Kehamilan                -0.073535  0.017683                 -0.033523
# ...

# %%
plt.figure(figsize=(6, 4))
sns.heatmap(df.corr(), annot=True, cmap='Blues')
plt.show()

# %% [markdown]
# ##4. Prepation Data

# %%
x = df.drop(columns=['Hasil']) # Changed 'coloumns' to 'columns'
y = df['Hasil']

print("x : ", x.shape)
print("y : ", y.shape)
# Out:
# x :  (768, 8)
# y :  (768,)

# %%
scaler = StandardScaler()
scaler.fit(x)
x = scaler.transform(x)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# ##5. Modeling & Evalution

# %%
clf = SVC(kernel='linear')
clf.fit(x_train, y_train)

y_pred = clf.predict(x_test)
CLF_acc = accuracy_score(y_test, y_pred)

print(classification_report(y_test, y_pred))
print("Akurasi SVM : {:.2f}%".format(CLF_acc*100))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.82      0.81        99
#            1       0.67      0.65      0.66        55
#
#     accuracy                           0.76       154
#    macro avg       0.74      0.74      0.74       154
# weighted avg       0.76      0.76      0.76       154
#
# Akurasi SVM : 75.97%

# %% [markdown]
# ##6. Testing

# %%
new_data = {'Kehamilan': [1],
            'Glukosa': [85],
            'Tekanan Darah': [66],
            'Ketebalan Kulit': [29],
            'Insulin': [0],
            'BMI': [26.6], # Changed [26,6] to [26.6] to match the length of other columns.
            'DiabetesPedigreeFunction' : [0.351],
            'Umur': [31]}

new_data = pd.DataFrame(new_data)
new_data
# Out:
#    Kehamilan  Glukosa  Tekanan Darah  Ketebalan Kulit  Insulin   BMI  \
# 0          1       85             66               29        0  26.6
#
#    DiabetesPedigreeFunction  Umur
# 0                     0.351    31

# %%
scaled_new_data = scaler.transform(new_data)
y_pred_new = clf.predict(scaled_new_data)

print("Diagnosis Data Baru : ", y_pred_new)
# Out:
# Diagnosis Data Baru :  [0]
